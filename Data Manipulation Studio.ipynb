# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df_blt = pd.read_csv('dataset/baltimore_9-24-2016_9-30-2017.csv')
df_bos = pd.read_csv('dataset/boston_9-24-2016_9-30-2017.csv')
df_phi = pd.read_csv('dataset/philadelphia_9-24-2016_9-30-2017.csv')
df_ny = pd.read_csv('dataset/new-york_9-24-2016_9-30-2017.csv')

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
df_ny.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/24/2016        150         170  ...    NaN          NaN
# 1    NaN  09/24/2016        150         170  ...    NaN          NaN
# 2    NaN  09/24/2016        130         150  ...    NaN          NaN
# 3    NaN  09/24/2016        130         150  ...    NaN          NaN
# 4    NaN  09/24/2016        120         140  ...    NaN          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# ...

# %%
df_blt.head()
# Out:
#   Commodity Name  City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 1       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 2       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  04/29/2017        270       280.0  ...    NaN          NaN
# 1    NaN  05/06/2017        270       280.0  ...    NaN          NaN
# 2    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 3    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 4    NaN  11/05/2016         90       100.0  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# ...

# %%
df_bos.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...   Color  Environment  \
# 0    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 1    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 2    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 3    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 4    NaN  09/24/2016        160         180  ...  ORANGE          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# ...

# %%
df_phi.head()
# Out:
#   Commodity Name     City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  PHILADELPHIA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/16/2017        140         150  ...    NaN          NaN
# 1    NaN  09/24/2016        150         150  ...    NaN          NaN
# 2    NaN  09/24/2016        150         150  ...    NaN          NaN
# 3    NaN  09/24/2016        150         160  ...    NaN          NaN
# 4    NaN  10/01/2016        140         140  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition  Appearance  Storage Crop  Repack  \
# ...

# %%
df_ny.duplicated(subset=None, keep='first')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 107    False
# 108    False
# 109    False
# 110    False
# 111    False
# Length: 112, dtype: bool

# %%
df_blt.duplicated(subset=None, keep='first')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 148    False
# 149    False
# 150    False
# 151    False
# 152    False
# Length: 153, dtype: bool

# %%
df_bos.duplicated(subset=None, keep='first')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 347    False
# 348    False
# 349    False
# 350    False
# 351    False
# Length: 352, dtype: bool

# %%
df_phi.duplicated(subset=None, keep='first')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# dtype: bool

# %%
df_ny.drop_duplicates()
# Out:
#     Commodity Name City Name  Type              Package      Variety  \
# 0         PUMPKINS  NEW YORK   NaN         36 inch bins  HOWDEN TYPE
# 1         PUMPKINS  NEW YORK   NaN         36 inch bins  HOWDEN TYPE
# 2         PUMPKINS  NEW YORK   NaN         36 inch bins  HOWDEN TYPE
# 3         PUMPKINS  NEW YORK   NaN         36 inch bins  HOWDEN TYPE
# 4         PUMPKINS  NEW YORK   NaN         36 inch bins  HOWDEN TYPE
# ..             ...       ...   ...                  ...          ...
# 107       PUMPKINS  NEW YORK   NaN       bushel cartons    MINIATURE
# 108       PUMPKINS  NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
# 109       PUMPKINS  NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
# 110       PUMPKINS  NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
# 111       PUMPKINS  NEW YORK   NaN  1 1/9 bushel crates    MINIATURE
#
#     Sub Variety  Grade        Date  Low Price  High Price  ...  Color  \
# ...

# %%
df_blt.drop_duplicates()
# Out:
#     Commodity Name  City Name  Type             Package      Variety  \
# 0         PUMPKINS  BALTIMORE   NaN        24 inch bins          NaN
# 1         PUMPKINS  BALTIMORE   NaN        24 inch bins          NaN
# 2         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 3         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 4         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# ..             ...        ...   ...                 ...          ...
# 148       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 149       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 150       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 151       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 152       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
#
#     Sub Variety  Grade        Date  Low Price  High Price  ...   Color  \
# ...

# %%
df_bos.drop_duplicates()
# Out:
#     Commodity Name City Name  Type             Package      Variety  \
# 0         PUMPKINS    BOSTON   NaN        36 inch bins  HOWDEN TYPE
# 1         PUMPKINS    BOSTON   NaN        36 inch bins  HOWDEN TYPE
# 2         PUMPKINS    BOSTON   NaN        36 inch bins  HOWDEN TYPE
# 3         PUMPKINS    BOSTON   NaN        36 inch bins  HOWDEN TYPE
# 4         PUMPKINS    BOSTON   NaN        36 inch bins  HOWDEN TYPE
# ..             ...       ...   ...                 ...          ...
# 347       PUMPKINS    BOSTON   NaN  1/2 bushel cartons    MINIATURE
# 348       PUMPKINS    BOSTON   NaN  1/2 bushel cartons    MINIATURE
# 349       PUMPKINS    BOSTON   NaN  1/2 bushel cartons    MINIATURE
# 350       PUMPKINS    BOSTON   NaN  1/2 bushel cartons    MINIATURE
# 351       PUMPKINS    BOSTON   NaN  1/2 bushel cartons    MINIATURE
#
#     Sub Variety  Grade        Date  Low Price  High Price  ...   Color  \
# 0           NaN    NaN  09/24/2016        160         200  ...  ORANGE
# ...

# %%
df_phi.drop_duplicates()
# Out:
#    Commodity Name     City Name  Type               Package       Variety  \
# 0        PUMPKINS  PHILADELPHIA   NaN          24 inch bins   HOWDEN TYPE
# 1        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 2        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 3        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 4        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 5        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 6        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 7        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 8        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 9        PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 10       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# 11       PUMPKINS  PHILADELPHIA   NaN          36 inch bins   HOWDEN TYPE
# ...

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
neregion = pd.concat([df_blt, df_bos, df_phi, df_ny], axis=0)

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
neregion_unit_sales = neregion.groupby('Unit of Sale')
neregion_unit_sales.first()
# Out:
#              Commodity Name     City Name  Type             Package  \
# Unit of Sale
# EACH               PUMPKINS     BALTIMORE   NaN        24 inch bins
# PER BIN            PUMPKINS        BOSTON   NaN        36 inch bins
# SHELLACKED         PUMPKINS  PHILADELPHIA   NaN  1/2 bushel cartons
#
#                     Variety Sub Variety  Grade        Date  Low Price  \
# Unit of Sale
# EACH          BIG MACK TYPE        None    NaN  09/24/2016         50
# PER BIN         HOWDEN TYPE        None    NaN  09/23/2017        200
# SHELLACKED        MINIATURE   FLAT TYPE    NaN  09/24/2016         17
#
#               High Price  ...  Item Size   Color Environment Quality  \
# Unit of Sale              ...
# EACH                60.0  ...        jbo   WHITE         NaN     NaN
# PER BIN            225.0  ...        jbo  ORANGE         NaN     NaN
# SHELLACKED          18.0  ...       None    None         NaN     NaN
#
#              Condition Appearance  Storage  Crop  Repack  Trans Mode
# ...

# %%
#neregion_unit_sales.agg("mean", axis="columns")

neregion_unit_sales.agg({'Low Price' : ['min', 'max'], 'High Price' : ['min', 'max']})
# Out:
#              Low Price      High Price
#                    min  max        min    max
# Unit of Sale
# EACH                40   50       50.0   60.0
# PER BIN            120  300      140.0  300.0
# SHELLACKED          15   18       15.0   20.0

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
neregion_number_pumpkins = neregion.groupby('Variety')
neregion_number_pumpkins.first()
# Out:
#                          Commodity Name  City Name  Type  \
# Variety
# BIG MACK TYPE                  PUMPKINS  BALTIMORE   NaN
# BLUE TYPE                      PUMPKINS     BOSTON   NaN
# CINDERELLA                     PUMPKINS  BALTIMORE   NaN
# FAIRYTALE                      PUMPKINS  BALTIMORE   NaN
# HOWDEN TYPE                    PUMPKINS  BALTIMORE   NaN
# HOWDEN WHITE TYPE              PUMPKINS  BALTIMORE   NaN
# KNUCKLE HEAD                   PUMPKINS     BOSTON   NaN
# MINIATURE                      PUMPKINS  BALTIMORE   NaN
# MIXED HEIRLOOM VARIETIES       PUMPKINS  BALTIMORE   NaN
# PIE TYPE                       PUMPKINS  BALTIMORE   NaN
#
#                                        Package Sub Variety  Grade        Date  \
# Variety
# BIG MACK TYPE                     24 inch bins        None    NaN  09/24/2016
# BLUE TYPE                         24 inch bins        None    NaN  09/24/2016
# CINDERELLA                        24 inch bins        None    NaN  06/03/2017
# ...

# %%
neregion_number_pumpkins.mean('Unit of Sale')
# Out:
#               Type  Grade   Low Price  High Price  Mostly Low  Mostly High  \
# City Name
# BALTIMORE      NaN    NaN  101.490196  109.055556  101.490196   108.859477
# BOSTON         NaN    NaN  162.840909  187.235795  172.721591   176.130682
# NEW YORK       NaN    NaN  107.125000  116.482143  107.312500   116.410714
# PHILADELPHIA   NaN    NaN   98.140351  103.754386   98.491228   103.754386
#
#               Environment  Quality  Condition  Appearance  Storage  Crop  \
# City Name
# BALTIMORE             NaN      NaN        NaN         NaN      NaN   NaN
# BOSTON                NaN      NaN        NaN         NaN      NaN   NaN
# NEW YORK              NaN      NaN        NaN         NaN      NaN   NaN
# PHILADELPHIA          NaN      NaN        NaN         NaN      NaN   NaN
#
#               Trans Mode
# City Name
# BALTIMORE            NaN
# BOSTON               NaN
# NEW YORK             NaN
# PHILADELPHIA         NaN

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
